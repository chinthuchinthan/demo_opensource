# %% [markdown]
# <a href="https://colab.research.google.com/github/chinthuchinthan/demo_opensource/blob/master/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'Temperature':['Hot','Cold','Warm','Cold'],})
print(df)
# Out:
#   Temperature
# 0         Hot
# 1        Cold
# 2        Warm
# 3        Cold

# %%
pd.get_dummies(df,dtype=(int))
# Out:
#    Temperature_Cold  Temperature_Hot  Temperature_Warm
# 0                 0                1                 0
# 1                 1                0                 0
# 2                 0                0                 1
# 3                 1                0                 0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Temperature_Cold'].plot(kind='hist', bins=20, title='Temperature_Cold')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Temperature_Hot'].plot(kind='hist', bins=20, title='Temperature_Hot')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Temperature_Warm'].plot(kind='hist', bins=20, title='Temperature_Warm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
